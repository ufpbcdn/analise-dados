# %% [markdown]
# - Fonte dos dados: https://dados-abertos.tce.pb.gov.br/

# %%
file = '/Users/alessiotony/Downloads/despesas-2025.csv'

import pandas as pd

df = pd.read_csv(file, sep=';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387532 entries, 0 to 2387531
# Data columns (total 40 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   municipio                       object
#  1   codigo_unidade_gestora          float64
#  2   descricao_unidade_gestora       object
#  3   numero_empenho                  int64
#  4   data_empenho                    object
#  5   mes                             object
#  6   cpf_cnpj                        int64
#  7   nome_credor                     object
#  8   valor_empenhado                 object
#  9   valor_liquidado                 object
#  10  valor_pago                      object
#  11  codigo_unidade_orcamentaria     int64
#  12  descricao_unidade_orcamentaria  object
#  13  codigo_funcao                   int64
#  14  funcao                          object
#  15  codigo_subfuncao                int64
#  16  subfuncao                       object
#  17  codigo_programa                 int64
#  18  programa                        object
#  19  codigo_acao                     int64
#  20  acao                            object
#  21  codigo_categoria_economica      int64
#  22  categoria_economica             object
#  23  codigo_natureza                 int64
#  24  grupo_natureza_despesa          object
#  25  codigo_modalidade_aplicacao     int64
#  26  modalidade_aplicacao            object
#  27  codigo_elemento_despesa         int64
#  28  elemento_despesa                object
#  29  codigo_subelemento              int64
#  30  codigo_subelemento_exibicao     object
#  31  numero_licitacao                int64
#  32  modalidade_licitacao            object
#  33  numero_obra                     int64
#  34  historico                       object
#  35  codigo_fonte_recurso            int64
#  36  descricao_fonte_recurso         object
#  37  ano_fonte                       int64
#  38  co                              float64
#  39  descricao_co                    object
# dtypes: float64(2), int64(16), object(22)
# memory usage: 728.6+ MB

# %%
# %pip install pyreaddbc
# Out:
# Requirement already satisfied: pyreaddbc in /opt/homebrew/lib/python3.13/site-packages (2.0.4)
# Requirement already satisfied: dbfread<3,>=2.0.7 in /opt/homebrew/lib/python3.13/site-packages (from pyreaddbc) (2.0.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyreaddbc.readdbc as r
from dbfread import DBF

datadir = '/Users/alessiotony/Downloads/'
dbc_path = datadir + 'DOPB2024.dbc'
dbf_path = datadir + 'DOPB2024.dbf'

r.dbc2dbf(dbc_path, dbf_path)

table = DBF(str(dbf_path), load=True, 
            char_decode_errors="ignore")
df = pd.DataFrame(iter(table))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30153 entries, 0 to 30152
# Data columns (total 87 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ORIGEM      30153 non-null  object
#  1   TIPOBITO    30153 non-null  object
#  2   DTOBITO     30153 non-null  object
#  3   HORAOBITO   30153 non-null  object
#  4   NATURAL     30153 non-null  object
#  5   CODMUNNATU  30153 non-null  object
#  6   DTNASC      30153 non-null  object
#  7   IDADE       30153 non-null  object
#  8   SEXO        30153 non-null  object
#  9   RACACOR     30153 non-null  object
#  10  ESTCIV      30153 non-null  object
#  11  ESC         30153 non-null  object
#  12  ESC2010     30153 non-null  object
#  13  SERIESCFAL  30153 non-null  object
#  14  OCUP        30153 non-null  object
#  15  CODMUNRES   30153 non-null  object
#  16  LOCOCOR     30153 non-null  object
#  17  CODESTAB    30153 non-null  object
#  18  ESTABDESCR  30153 non-null  object
#  19  CODMUNOCOR  30153 non-null  object
#  20  IDADEMAE    30153 non-null  object
#  21  ESCMAE      30153 non-null  object
#  22  ESCMAE2010  30153 non-null  object
#  23  SERIESCMAE  30153 non-null  object
#  24  OCUPMAE     30153 non-null  object
#  25  QTDFILVIVO  30153 non-null  object
#  26  QTDFILMORT  30153 non-null  object
#  27  GRAVIDEZ    30153 non-null  object
#  28  SEMAGESTAC  30153 non-null  object
#  29  GESTACAO    30153 non-null  object
#  30  PARTO       30153 non-null  object
#  31  OBITOPARTO  30153 non-null  object
#  32  PESO        30153 non-null  object
#  33  TPMORTEOCO  30153 non-null  object
#  34  OBITOGRAV   30153 non-null  object
#  35  OBITOPUERP  30153 non-null  object
#  36  ASSISTMED   30153 non-null  object
#  37  EXAME       30153 non-null  object
#  38  CIRURGIA    30153 non-null  object
#  39  NECROPSIA   30153 non-null  object
#  40  LINHAA      30153 non-null  object
#  41  LINHAB      30153 non-null  object
#  42  LINHAC      30153 non-null  object
#  43  LINHAD      30153 non-null  object
#  44  LINHAII     30153 non-null  object
#  45  CAUSABAS    30153 non-null  object
#  46  CB_PRE      30153 non-null  object
#  47  COMUNSVOIM  30153 non-null  object
#  48  DTATESTADO  30153 non-null  object
#  49  CIRCOBITO   30153 non-null  object
#  50  ACIDTRAB    30153 non-null  object
#  51  FONTE       30153 non-null  object
#  52  NUMEROLOTE  30153 non-null  object
#  53  TPPOS       30153 non-null  object
#  54  DTINVESTIG  30153 non-null  object
#  55  CAUSABAS_O  30153 non-null  object
#  56  DTCADASTRO  30153 non-null  object
#  57  ATESTANTE   30153 non-null  object
#  58  STCODIFICA  30153 non-null  object
#  59  CODIFICADO  30153 non-null  object
#  60  VERSAOSIST  30153 non-null  object
#  61  VERSAOSCB   30153 non-null  object
#  62  FONTEINV    30153 non-null  object
#  63  DTRECEBIM   30153 non-null  object
#  64  ATESTADO    30153 non-null  object
#  65  DTRECORIGA  30153 non-null  object
#  66  CAUSAMAT    30153 non-null  object
#  67  ESCMAEAGR1  30153 non-null  object
#  68  ESCFALAGR1  30153 non-null  object
#  69  STDOEPIDEM  30153 non-null  object
#  70  STDONOVA    30153 non-null  object
#  71  DIFDATA     30153 non-null  object
#  72  NUDIASOBCO  30153 non-null  object
#  73  NUDIASOBIN  30153 non-null  object
#  74  DTCADINV    30153 non-null  object
#  75  TPOBITOCOR  30153 non-null  object
#  76  DTCONINV    30153 non-null  object
#  77  FONTES      30153 non-null  object
#  78  TPRESGINFO  30153 non-null  object
#  79  TPNIVELINV  30153 non-null  object
#  80  NUDIASINF   30153 non-null  object
#  81  DTCADINF    30153 non-null  object
#  82  MORTEPARTO  30153 non-null  object
#  83  DTCONCASO   30153 non-null  object
#  84  FONTESINF   30153 non-null  object
#  85  ALTCAUSA    30153 non-null  object
#  86  CONTADOR    30153 non-null  object
# dtypes: object(87)
# memory usage: 20.0+ MB
