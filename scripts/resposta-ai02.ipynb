# %% [markdown]
# # AI-02 Fundamentos Python para Análise de Dados
# - Aléssio Almeida (alessio@lema.ufpb.br)

# %% [markdown]
# ## Questão 01

# %%
# O usuário vai informar o número
try:
    num = float(input("Digite um número:"))
    if num == 0:
        msg = f"O número <{num}> é igual a zero."
    elif num < 0:
        msg = f"O número <{num}> é negativo."
    else:
        msg = f"O número <{num}> é positivo."
    print(msg)
except:
    print("Você não digitou um número.")
# Out:
# O número <12.0> é positivo.

# %% [markdown]
# ## Questão 08
# Copie as informações abaixo (ctrl+c)
# ```
# Produto,Preco,Quantidade,Data
# A,10.0,5,2024-01-15
# B,25.5,2,2024-01-15
# A,10.0,3,2024-01-16
# C,12.0,1,2024-01-16
# ```

# %%
import pandas as pd
from pandas import read_clipboard, read_csv # Importação seletiva

# a)
df = pd.read_clipboard(sep=',')
print("a)")
print(df.info())

# b) 
print("b)",df.head(n=2))

# c)
df['Total_Vendas'] = df['Preco'] * df['Quantidade']
df=df.assign(Total_Vendas_2 = lambda x: x.Preco * x.Quantidade)
print("c)",df.head())
# d)
print("d)", df.sort_values('Total_Vendas', ascending=False).head(1).Produto)
# Out:
# a)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Produto     4 non-null      object
#  1   Preco       4 non-null      float64
#  2   Quantidade  4 non-null      int64
#  3   Data        4 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 260.0+ bytes
# None
# b)   Produto  Preco  Quantidade        Data
# 0       A   10.0           5  2024-01-15
# 1       B   25.5           2  2024-01-15
# c)   Produto  Preco  Quantidade        Data  Total_Vendas  Total_Vendas_2
# 0       A   10.0           5  2024-01-15          50.0            50.0
# 1       B   25.5           2  2024-01-15          51.0            51.0
# 2       A   10.0           3  2024-01-16          30.0            30.0
# 3       C   12.0           1  2024-01-16          12.0            12.0
# d 1    B
# Name: Produto, dtype: object

# %% [markdown]
# ## Questão 12 - Desafio 1
#
# a) Os dados extraídos foram o Censo Escolar 2025 (INEP).
#
# - url_acesso: https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/censo-escolar
#
# - url_download:
# https://download.inep.gov.br/dados_abertos/microdados_censo_escolar_2025_.zip
#
# - Baixe os dados e descompacte.
#
# - Disponha os arquivos na pasta: `~/Data/INEP/CENSO_ESCOLAR/2025`

# %%
# Início da letra b)
selecao = ['NU_ANO_CENSO', 'NO_REGIAO', 'SG_UF', 'CO_UF', 
           'NO_MUNICIPIO', 'CO_MUNICIPIO', 'NO_ENTIDADE', 
           'CO_ENTIDADE', 'TP_DEPENDENCIA', 'IN_AGUA_POTAVEL'] #... colocar outras
filename = '/Users/alessiotony/Data/INEP/CENSO_ESCOLAR/2025/dados/Tabela_Escola_2025.csv'
df = pd.read_csv(filename, encoding='latin1', sep=';',
                 usecols=selecao)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214192 entries, 0 to 214191
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   NU_ANO_CENSO     214192 non-null  int64
#  1   NO_REGIAO        214192 non-null  object
#  2   SG_UF            214192 non-null  object
#  3   CO_UF            214192 non-null  int64
#  4   NO_MUNICIPIO     214192 non-null  object
#  5   CO_MUNICIPIO     214192 non-null  int64
#  6   NO_ENTIDADE      214192 non-null  object
#  7   CO_ENTIDADE      214192 non-null  int64
#  8   TP_DEPENDENCIA   214192 non-null  int64
#  9   IN_AGUA_POTAVEL  180540 non-null  float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.3+ MB
